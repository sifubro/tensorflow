# %%
# from keras.engine import base_layer
# from keras.engine import base_preprocessing_layer

from tensorflow.python.keras.engine import base_layer
from tensorflow.python.keras.engine import base_preprocessing_layer

# %%
# !pip install keras-preprocessing

# %%
# Replace keras.engine
# with tensorflow.python.keras.engine

# %%
import tensorflow as tf
# from keras.engine import base_layer
# from keras.engine import base_preprocessing_layer
from tensorflow.python.keras.engine import base_layer
from tensorflow.python.keras.engine import base_preprocessing_layer

# %%
from tensorflow.python.keras.layers import Rescaling

# %%
#normalization_layer = tf.keras.layers.Rescaling(1./255)
normalization_layer = Rescaling(1./255)

# %%
def map_fn(x,y)

# %%
from keras.layers.experimental.preprocessing import Rescaling
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7332/4290348042.py in <module>
# ----> 1 from keras.layers.experimental.preprocessing import Rescaling
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      17
#      18 import tensorflow.compat.v2 as tf
# ---> 19 from keras import backend
#      20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\backend.py in <module>
#      34 from tensorflow.core.protobuf import config_pb2
# ...

# %%
from keras.layers import Resizing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7332/3021297701.py in <module>
# ----> 1 from keras.layers import Resizing
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      17
#      18 import tensorflow.compat.v2 as tf
# ---> 19 from keras import backend
#      20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\backend.py in <module>
#      34 from tensorflow.core.protobuf import config_pb2
# ...

# %%
from tensorflow.keras.preprocessing import image_preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7332/3234356641.py in <module>
# ----> 1 from tensorflow.keras.preprocessing import image_preprocessing
#
# ImportError: cannot import name 'image_preprocessing' from 'tensorflow.keras.preprocessing' (c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\keras\preprocessing\__init__.py)

# %%
from keras.layers.preprocessing import image_preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7332/1379034164.py in <module>
# ----> 1 from keras.layers.preprocessing import image_preprocessing
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      17
#      18 import tensorflow.compat.v2 as tf
# ---> 19 from keras import backend
#      20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\backend.py in <module>
#      34 from tensorflow.core.protobuf import config_pb2
# ...

# %%
from tensorflow.keras.preprocessing import image_preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7332/3234356641.py in <module>
# ----> 1 from tensorflow.keras.preprocessing import image_preprocessing
#
# ImportError: cannot import name 'image_preprocessing' from 'tensorflow.keras.preprocessing' (c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\keras\preprocessing\__init__.py)

# %%
import tensorflow

# %%
tensorflow.keras.preprocessing.

# %%
from tensorflow import keras

# %%
keras.preprocessing.image.

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6124/3208813603.py in <module>
# ----> 1 import keras
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      17
#      18 import tensorflow.compat.v2 as tf
# ---> 19 from keras import backend
#      20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\backend.py in <module>
#      34 from tensorflow.core.protobuf import config_pb2
# ...

# %%
from tensorflow.python.keras.preprocessing import image_preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7332/3821478854.py in <module>
# ----> 1 from tensorflow.python.keras.preprocessing import image_preprocessing
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\preprocessing\image_preprocessing.py in <module>
#      19
#      20 import numpy as np
# ---> 21 from keras import backend
#      22 from keras.engine import base_layer
#      23 from keras.engine import base_preprocessing_layer
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# c:\users\sifubro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      17
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_preprocessing

normalization_layer = tf.python.keras.preprocessing.image_preprocessing.Rescaling(1./255) #[0,1] normalization
# tf.keras.layers.Rescaling(1./127.5, offset=-1)  # [-1,1] normalization

normalized_ds_tr = train_ds.map(lambda x, y:(normalization_layer(x), y))
normalized_ds_val = val_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16164/556955252.py in <module>
#       1 import tensorflow as tf
# ----> 2 from tensorflow.keras.layers.preprocessing import image_preprocessing
#       3
#       4 normalization_layer = tf.python.keras.preprocessing.image_preprocessing.Rescaling(1./255) #[0,1] normalization
#       5 # tf.keras.layers.Rescaling(1./127.5, offset=-1)  # [-1,1] normalization
#
# ModuleNotFoundError: No module named 'tensorflow.keras.layers.preprocessing'

# %%
import sys
[item for item in sys.modules.keys() if 'tensorflow' in item]
# Out:
# ['tensorflow.python.platform',
#  'tensorflow.python.platform.build_info',
#  'tensorflow.python.platform.self_check',
#  'tensorflow.python.pywrap_dlopen_global_flags',
#  'tensorflow.python._pywrap_tensorflow_internal',
#  'tensorflow.python.pywrap_tensorflow',
#  'tensorflow.python.eager',
#  'tensorflow.core',
#  'tensorflow.core.framework',
#  'tensorflow.core.framework.tensor_shape_pb2',
#  'tensorflow.core.framework.types_pb2',
#  'tensorflow.core.framework.resource_handle_pb2',
#  'tensorflow.core.framework.tensor_pb2',
#  'tensorflow.core.framework.attr_value_pb2',
#  'tensorflow.core.framework.node_def_pb2',
#  'tensorflow.core.framework.op_def_pb2',
#  'tensorflow.core.framework.function_pb2',
#  'tensorflow.core.protobuf',
#  'tensorflow.core.framework.cost_graph_pb2',
#  'tensorflow.core.framework.versions_pb2',
#  'tensorflow.core.framework.graph_pb2',
#  'tensorflow.core.framework.allocation_description_pb2',
#  'tensorflow.core.framework.tensor_description_pb2',
# ...
